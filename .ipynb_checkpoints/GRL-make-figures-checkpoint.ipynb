# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import pandas as pd
from scipy import optimize
import seaborn as sns
from scipy.stats import linregress
import matplotlib.colors as colors
from scipy.stats import linregress
import os
import csv

# %% [markdown]
# ## Functions needed to make the plots:

# %%
def cumul_prob(data):
    data = np.sort(data)
    return np.array([(data[i] < data).sum() for i in range(len(data))])

def normed_CPD(data):
    data = np.sort(data)
    prob = [(data[i] < data).sum() for i in range(len(data))]
    return prob / max(prob)

def calc_alpha(data, low_cutoff = None, high_cutoff = None):
    data = np.sort(data)
    if high_cutoff == None:
        high_cutoff = max(data)
    if low_cutoff == None:
        low_cutoff = min(data)
    data_cut = data[(data >= low_cutoff) & (data <= high_cutoff)]
    return 1 + len(data_cut) * (np.sum(np.log(data_cut / low_cutoff)))**-1

def calc_sigma(data, alpha, low_cutoff = None, high_cutoff = None):
    data = np.sort(data)
    if high_cutoff == None:
        high_cutoff = max(data)
    if low_cutoff == None:
        low_cutoff = min(data)
    data_cut = data[(data >= low_cutoff) & (data <= high_cutoff)]
    return (alpha - 1) / np.sqrt(len(data_cut))

def find_unique_areas(areas):
    uniques, counts = np.unique(areas, return_counts = True)
    counts = counts.astype(str)
    area_list = []
    count_list = []
    area_list.append(uniques)
    count_list.append(counts)
    return np.vstack((area_list, count_list)).T

def find_unique_pairs(data):
    uniques = np.unique(data)
    p1_list = []
    p2_list = []
    for n in uniques:
        index = np.where(uniques == n)
        index_n = int(index[0])
        for i in uniques[index_n + 1:]:
            p1_list.append(n)
            p2_list.append(i)
    return np.column_stack((p1_list, p2_list))

def max_likelihood_alpha(data, alpha, low_cutoff, high_cutoff):
    c = low_cutoff / high_cutoff
    data_cut = data[(data >= low_cutoff) & (data <= high_cutoff)]
    L = np.log((alpha - 1) / (1 - c**(alpha - 1))) - alpha * (np.sum(np.log(data_cut) / low_cutoff)) / len(data_cut)
    return L

def powerlaw_dist(exponent, low_cutoff, size = 2000):
    r = np.linspace(0, 0.99, size)
    pl_dist = low_cutoff * (1 - r)**(-1/(exponent - 1))
    return pl_dist

def powerlaw_bestFit(data, guess_low_cutoff, guess_upper_cutoff, step_size, pval_thresh):
    alpha = calc_alpha(data, guess_low_cutoff)
    a_range = np.arange(alpha - 0.1, alpha + 0.1, 0.01)
    cutoff_range = np.arange(0, guess_upper_cutoff, step_size)
    st_save = 1
    for a in a_range:
        for c in cutoff_range:
            data_cut = data[data > c]
            pl = powerlaw_dist(a, c)
            st, pval = stats.kstest(pl, data_cut)
            if st < st_save:
                st_save = np.round(st, 3)
                pval_save = np.round(pval, 3)
                a_save = np.round(a, 3)
                c_save = np.round(c, 3)
    if pval_save > pval_thresh:
        print('Fail to reject null hypothesis p > {}. Distributions are the same.'.format(pval_thresh))
        print('KS-statistic = {}, p = {}, alpha = {}, low cutoff = {}'.format (st_save, pval_save, a_save, c_save))
    elif pval_save < pval_thresh:
        print('Reject null hypothesis p < {}. Distributions are different.'.format(pval_thresh))
        print('KS-statistic = {}, p = {}, alpha = {}, low cutoff = {}'.format (st_save, pval_save, a_save, c_save))
    return a_save, c_save, st_save, pval_save

# %% [markdown]
# ## Import the data

# %%
#Type the file path to the data CSV file
path_to_data = 'C:/Users/rstrickland/Dropbox/scale-invariance-manuscript_GRL/GRL_model-output/1-5_m_output_new/n1000-csvs/1-5_m_1000_sim-0.csv'

data = pd.read_csv(path_to_data)

# %% [markdown]
# ## For Ngozumpa Glacier data: Prepare a .dat file to check distribution for a power law fit and to approximate tail exponents

# %% [markdown]
# ### After making the .dat file, open a terminal and run the Voitalov et a. (2019) tail estimation python script. Follow the instructions on https://github.com/ivanvoitalov/tail-estimation

# %%
name_of_dat_file = '' + '.dat'

areas = data['area']
x = find_unique_areas(areas)
with open(name_of_dat_file, 'w', newline = '') as f:
    writer = csv.writer(f, delimiter = ' ')
    for i in range(len(x)):
        writer.writerow(x[i,:])

# %% [markdown]
# ## For model data: Prepare a .dat file to check the distribution for a power law fit and to approximate tail exponents
#
# ### Figures used in the paper combined the data from the terminating time step of 10 simulations for a given set of parameters. Place each of the simulation data files for a set of parameters into a directory, then run the script below to create the .dat file.

# %%
simulation = 'C:/Users/rstrickland/Desktop/depression-growth-model/run-all-again/1_m_output/csv-files/n1000/1_m_1000_sim-0.csv' 
name_of_dat_file = 'C:/Users/rstrickland/Desktop/depression-growth-model/run-all-again/1_m_output/csv-files/1_m_1000_sim-0.dat'

areas = []
df = pd.read_csv(simulation)
last_step = df.iloc[:,-1]
areas.extend(last_step)
        
#Remove the NaN values        
areas = np.array(areas)
areas = areas[~np.isnan(areas)]

x = find_unique_areas(areas)
with open(name_of_dat_file, 'w', newline = '') as f:
    writer = csv.writer(f, delimiter = ' ')
    for i in range(len(x)):
        writer.writerow(x[i,:])

# %%
simulations_dir = 'C:/Users/rstrickland/Desktop/depression-growth-model/run-all-again/1-25_m_output/csv-files/n750' 
name_of_dat_file = 'C:/Users/rstrickland/Desktop/depression-growth-model/run-all-again/1-25_m_output/csv-files/1-25_m_750_all.dat'
areas = []
for f in os.listdir(simulations_dir):
    if f.endswith('.csv'):
        df = pd.read_csv(simulations_dir + '/' + f)
        last_step = df.iloc[:,-1]
        areas.extend(last_step)
        
        #Remove the NaN values        
areas = np.array(areas)
areas = areas[~np.isnan(areas)]

x = find_unique_areas(areas)
with open(name_of_dat_file, 'w', newline = '') as f:
    writer = csv.writer(f, delimiter = ' ')
    for i in range(len(x)):
        writer.writerow(x[i,:])

# %% [markdown]
# ### After making the .dat file, open a terminal and run the Voitalov et a. (2019) tail estimation python script. Follow the instructions on https://github.com/ivanvoitalov/tail-estimation

# %% [markdown]
# ## Make CCDF plot for simulations

# %%
simulations_dir = 'C:/Users/rstrickland/Desktop/depression-growth-model/GRL-figure' 

fig, ax = plt.subplots(3,2, figsize = (8,10))
axes = ax.flatten()

titles = ['r = 1, mergers', 'r = 1, no mergers','r = 1.25, mergers', 'r = 1.25, no mergers', 'r = 1.5, mergers', 'r = 1.5, no mergers']

i = 0
#Go through each sub directory
for d in os.listdir(simulations_dir):
    #Open each csv file
    for f in os.listdir(simulations_dir + '/' + d):
        if f.endswith('.csv'):
            areas = []
            #Take the depression areas from the last recorded time step
            df = pd.read_csv(simulations_dir + '/' + d + '/' + f)
            last_step = df.iloc[:,-1]
            areas.extend(last_step)

            #Remove the NaN values        
            areas = np.array(areas)
            areas = areas[~np.isnan(areas)]
            
            #Calculate the complementary cumulative probability density
            areasCPD = normed_CPD(areas)
            axes[i].set_title(d)
            axes[i].loglog(np.sort(areas), areasCPD, linewidth = 2)
            axes[i].set_xlim([10**-0.2,10**5.6])
            axes[i].set_ylim([10**-4,10**0.2])
    i += 1

plt.tight_layout()
plt.show()

# %%
simulations_dir = 'C:/Users/rstrickland/Desktop/depression-growth-model/run-all-again/1-25_nm_output/csv-files/n1250' 
fig, ax = plt.subplots()

for f in os.listdir(simulations_dir):
    if f.endswith('.csv'):
        areas = []
        df = pd.read_csv(simulations_dir + '/' + f)
        last_step = df.iloc[:,-1]
        areas.extend(last_step)
        
        #Remove the NaN values        
        areas = np.array(areas)
        areas = areas[~np.isnan(areas)]
        
        areasCPD = normed_CPD(areas)


        ax.loglog(np.sort(areas), areasCPD, linewidth = 3)
        
ax.set_xlabel('Area [m$^2$]', fontsize = 14)
ax.set_ylabel('$\overline{F}$(A)', fontsize = 14)

plt.show()

# %%
#areas = data['area']
areasCPD = normed_CPD(areas)

fig, ax = plt.subplots()
ax.loglog(np.sort(areas), areasCPD, linewidth = 3, color = 'dodgerblue')
ax.set_xlabel('Area [m$^2$]', fontsize = 14)
ax.set_ylabel('$\overline{F}$(A)', fontsize = 14)

plt.show()

# %% [markdown]
# ## Make perimeter-area fractal dimension plot

# %%
areas = data['area']
perimeters = data['perimeter']

fig, ax = plt.subplots()
ax.loglog(areas, perimeters, 'o', markersize = 1, alpha = 1, color = 'forestgreen')
ax.set_xlabel('Area [m$^2$]', fontsize = 14)
ax.set_ylabel('Perimeter [m]', fontsize = 14)

plt.show()

# %% [markdown]
# ## Make depth-area plot

# %%
areas = data['area']
depths = data['_max']

fig, ax = plt.subplots()
ax.loglog(areas, depths, 'o', markersize = 1, alpha = 1, color = 'darkred')
ax.set_xlabel('Area [m$^2$]', fontsize = 14)
ax.set_ylabel('Depth [m]', fontsize = 14)

plt.show()

# %%
sinks_2010 = pd.read_csv('2010_Ngo_sinks.csv')

sinks_2012 = pd.read_csv('2012_Ngo_sinks.csv')

sinks_2015 = pd.read_csv('2015_Ngo_sinks.csv')

sinks_2019 = pd.read_csv('2019_Ngo_sinks_1m.csv')

slope_test = pd.read_csv('2019_ngo_with-per-slopes.csv')

slope_test_1  = pd.read_csv('2019_Ngo-depressions_1m-borderdata.csv')

dfList = [sinks_2019]

# %%
sinks_2019['area'][sinks_2019['area']>=1].sum()/3300000 #approximate area of survey 6570462
# Out:
# 0.6022472727272727

# %%
sinks_2019['area'].sum()
# Out:
# 1987416

# %%
#Approximate amin, or define variable amin 
#alpha, amin, st, pval = powerlaw_bestFit(sinks_2019['area'], 10, 200, 10, 0.95)
alpha = 1.66
amin = 60
#Calculate probability densities
df = sinks_2019[sinks_2019['area'] >= 10]
data = df['area']
x2 = np.linspace(min(data), max(data)+100000, 5000)
cpd = (amin / x2)**(alpha - 1)
dataCPD = normed_CPD(data)
print(len(data), 'depressions')

#Calculate fractal dimensions
amin = 10
x3 = np.linspace(amin, max(data), 10)
x4 = np.linspace(1000, max(data), 10)
aranges = np.linspace(10, 10**5)
sqAreas = np.sqrt(data)
perimeters = df['perimeter']
restrict = df[df['area'] >= amin]
area_r = restrict['area']
perimeter_r = restrict['perimeter']
D, b, r, p, se = linregress(np.log10(np.sqrt(area_r)), np.log10(perimeter_r))
r_frac = r
restrict = df[df['area'] >= 10000]
area_r = restrict['area']
perimeter_r = restrict['perimeter']
D1, b1, r1, p1, se1 = linregress(np.log10(np.sqrt(area_r)), np.log10(perimeter_r))
tempfrac = df.sample(frac=1, random_state = 1)
perimeters = tempfrac['perimeter']
areasfrac = tempfrac['area']

#Calculate depression depth densities
slope_test = slope_test[slope_test['area'] >= 10]
areas = np.log10(slope_test['area'])
depth = np.log10(slope_test['_max'])
areamin = areas.min()
areamax = areas.max()
dmin = depth.min()
dmax = depth.max()
xd, yd = np.mgrid[areamin:areamax:200j, dmin:dmax:200j]
positionsd = np.vstack([xd.ravel(), yd.ravel()])
valuesd = np.vstack([areas, depth])
kerneld = stats.gaussian_kde(valuesd)
zd = np.reshape(kerneld(positionsd).T, yd.shape)
tempdepths = slope_test.sample(frac=1, random_state = 1)
areas = np.log10(tempdepths['area'])
depth = np.log10(tempdepths['_max'])

#Calculate power law relation for area-depth
tempdf = slope_test
tempdf = tempdf[tempdf['area'] >= 10]
tempareas = np.log10(tempdf['area'])
tempdepth = np.log10(tempdf['_max'])
slope, yint, rval, pval, se = linregress(tempareas, tempdepth)
r_depth = rval

#Calculate perimeter slope densities
slope_test = slope_test[slope_test['per-slope_median'].notna()]
area = np.log10(slope_test['area'])
median = slope_test['per-slope_median']
medMin = median.min()
medMax = median.max()
x, y = np.mgrid[areamin:areamax:200j, medMin:medMax:200j]
positions = np.vstack([x.ravel(), y.ravel()])
values = np.vstack([area, median])
kernel = stats.gaussian_kde(values)
z = np.reshape(kernel(positions).T, y.shape)
tempdensities = slope_test.sample(frac=0.2, random_state = 1)
area = np.log10(tempdensities['area'])
median = tempdensities['per-slope_median']
print(D/2, slope)
print("Fractal R^2 =", r_frac**2)
print("Depth R^2 =", r_depth**2)
# Out:
# 3073 depressions
# 0.5839161130643471 0.497552618155483
# Fractal R^2 = 0.9649396698351582
# Depth R^2 = 0.6844556136004449

# %%
temp = np.linspace(np.log10(10), areamax, 100)
fig, ax = plt.subplots(3,1, figsize = (4,8)) #, constrained_layout = True)

#Plot probability densities #dodgerblue
ax[0].loglog(np.sort(data), dataCPD, linewidth = 3, color = '#4d9fcc')#, markerfacecolor = 'none')
ax[0].loglog(x2, 0.5*cpd, linestyle = '--', dashes = (3,2), linewidth = 2, label = '$\\overline{F}(A) \propto A^{-0.68} $', color = 'k')
ax[0].legend(loc = (.35, .75), fontsize = 12, framealpha = 1, handlelength = 0, frameon = False)
ax[0].set_xlim([10**0.8, 10**5.6])
#ax[0].set_xlabel('Depression Area [m$^2$]', fontsize = 14)
ax[0].set_ylabel('$\\overline{F}(A)$', fontsize = 10)
ax[0].get_xaxis().set_ticks([10**1, 10**3, 10**5])
ax[0].get_yaxis().set_ticks([10**-4, 10**-3, 10**-2, 10**-1, 10**0])
ax[0].tick_params('both', length = 10, width = 1.2, which = 'major', labelsize = 8)
ax[0].tick_params('both', length = 0, width = 1, which = 'minor')
ax[0].annotate('(a)', xy = (-.3,1.1), xycoords = 'axes fraction', fontsize = 12)

#Plot fractal dimensions #forestgreen
ax[1].loglog(areasfrac, perimeters, 'o', markersize = 1.5, markerfacecolor = 'forestgreen', markeredgecolor = 'none')
#ax[1].loglog(x3, 10**b*x3**(D/2), linestyle = '--', dashes = (3,2), linewidth = 2, label = '$P \propto \\left(\sqrt{A}\\;\\right)^{^{1.18}}$', color = 'k')
ax[1].loglog(x3, 10**b*x3**(D/2), linestyle = '--', dashes = (3,2), linewidth = 2, label = '$P \propto A^{0.58}$', color = 'k')
#ax[1].loglog(x4, 10**b1*x4**(D1/2), linestyle = '--', dashes = (3,2), linewidth = 2, label = '$P \propto A^{1.18}$', color = 'k')
ax[1].loglog(x3, 3.6*x3**0.5,  linewidth = 1, color = 'k')
ax[1].legend(loc = (.23, .6), fontsize = 12, handlelength = 0, framealpha = 1, frameon = False)
ax[1].set_xlim([10**0.8, 10**5.6])
#ax[1].set_xlabel('Depression Area [m$^2$]', fontsize = 14)
ax[1].set_ylabel('Perimeter [m]', fontsize = 10)
ax[1].get_xaxis().set_ticks([10**1, 10**3, 10**5])
ax[1].tick_params('both', length = 10, width = 1.2, which = 'major', labelsize = 8)
ax[1].tick_params('both', length = 0, width = 1, which = 'minor')
ax[1].annotate('(b)', xy = (-0.3,1.1), xycoords = 'axes fraction', fontsize = 12)

#ax[2].imshow(np.rot90(zd), cmap = 'gist_heat_r', extent = [areamin, areamax, dmin, dmax], aspect = 'auto', norm = colors.Normalize(vmin = zd.min(), vmax = np.percentile(zd, q = 99)))
ax[2].plot(areas, depth, 'o', markersize = 1.5, markerfacecolor = 'darkred', markeredgecolor = 'none')
ax[2].plot(temp, slope * temp + yint, '--', c = 'k', linewidth = 2, label = '$d \propto A^{0.49}$') 
ax[2].get_xaxis().set_ticks([1,3,5])
ax[2].get_yaxis().set_ticks([-1, 0, 1])
ax[2].set_xticklabels(["$10^1$","$10^3$","$10^5$"], fontsize = 12)
ax[2].set_yticklabels(["$0.1$","$1$","$10$"], fontsize = 12)
ax[2].set_xlim([0.8, 5.6])
ax[2].set_ylabel('Depth [m]', fontsize = 10)
ax[2].tick_params(labelsize = 8)
ax[2].tick_params('both', length = 10, width = 1.2, which = 'major')
ax[2].legend(loc = (0.1,0.77), handlelength = 0, fontsize = 12, frameon = False)
ax[2].set_xlabel('Depression Area [m$^2$]', fontsize = 10)
ax[2].annotate('(c)', xy = (-.3,1.1), xycoords = 'axes fraction', fontsize = 12)


sns.despine(offset = 2)
#fig.subplots_adjust(hspace = 0.15, wspace = 0.25)
plt.tight_layout()
#plt.savefig('figure-2_GRL.png', dpi = 600)
plt.show()

# %%
slope_test = pd.read_csv('2019_ngo_with-per-slopes.csv')
slope_test = slope_test[slope_test['area'] >= 10]
slope_test = slope_test[slope_test['per-slope_mean'].notna()]

area = np.log10(slope_test['area'])
areamin = area.min()
areamax = area.max()

mean = slope_test['per-slope_mean']
meanmin = mean.min()
meanmax = mean.max()

#slp, bval, rval, pval, ste = linregress(area, mean)

#print(rval, pval)

rolling = slope_test['per-slope_mean'].sort_values().rolling(100).mean()
#rolling = slope_test.sort_values(by = ['area']).rolling(100).mean()
xs = np.arange(areamin, areamax, (areamax - areamin)/len(rolling))

x, y = np.mgrid[areamin:areamax:200j, meanmin:meanmax:200j]

positions = np.vstack([x.ravel(), y.ravel()])
values = np.vstack([area, mean])
kernel = stats.gaussian_kde(values)
z = np.reshape(kernel(positions).T, y.shape)

maxi = slope_test['per-slope_max']
med = slope_test['per-slope_median']
rng = slope_test['per-slope_range']

fig, ax = plt.subplots(figsize = (3.25, 3))
ax.imshow(np.rot90(z), cmap = sns.color_palette("light:lightskyblue", as_cmap = True), extent = [areamin, areamax, meanmin, meanmax], aspect = 0.1, norm = colors.Normalize(vmin = z.min(), vmax = np.percentile(z, q = 95)))
ax.plot(area, mean, '.', c = 'k', markersize = 0.3)
ax.plot(np.sort(area), rolling, color = 'k', linestyle = '-', linewidth = 2)
#ax.plot(np.log10(ma), ms, color = 'k')
#ax.plot(np.sort(area),color = 'C0', linewidth = 3, zorder = 4)
ax.set_xticks([2, 3, 4, 5])
ax.set_ylim(0,40)
ax.set_xticklabels(["$10^2$", "$10^3$", "$10^4$", "$10^5$"], fontsize = 12)
#ax.set_yticklabels([10, 15, 20, 25, 30, 35, 40, 45], fontsize = 14)
ax.axhline(27, c = 'k', linestyle = '--')
ax.set_xlabel('Area [m$^2$]', fontsize = 14)
ax.set_ylabel('Mean Perimeter Slope ($\circ$)', fontsize = 14)
ax.tick_params(labelsize = 12)

plt.show()
# Out:
#          fid  VALUE  area  perimeter      _max    _stdev  _variance  \
# 0          1      1    21         40  0.149902  0.037194   0.001383
# 2          3      1    56         56  0.692871  0.175916   0.030946
# 3          4      1   193        114  0.963379  0.200627   0.040251
# 4          5      1   672        216  4.694336  1.329539   1.767673
# 5          6      1   260        156  2.245605  0.523636   0.274195
# ...      ...    ...   ...        ...       ...       ...        ...
# 31319  31320      1   211        130  1.146973  0.295729   0.087455
# 31320  31321      1   181         76  3.335449  0.891986   0.795638
# 31321  31322      1   461        168  2.797363  0.722618   0.522177
# 31322  31323      1   282        146  2.133789  0.557803   0.311144
# 31323  31324      1   195        114  2.138184  0.418872   0.175454
#
#        flat-c_sum  per-slope_mean  per-slope_median  per-slope_range  \
# 0              21        1.123906          1.112661         2.249467
# ...
